# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#veri oluşturma
X_data = np.random.random(50)*100 #0-100 arası 50 tane sayı üretir
Y_data = np.random.random(50)*100 #0-100 arası 50 tane sayı üretir
print(X_data)
print(Y_data)
# Out:
# [92.05615253 61.50820589  3.40890687 82.86234432 76.06706561 38.5300949
#  57.64859658 67.47005958 28.74377167 67.12511746 38.84469817 42.6489229
#  76.71681277 69.62588994 29.62266384 63.79485735 79.82085957 57.25211519
#  17.7537341  90.10976663 31.11170477 59.53799696 99.62846034 74.95261655
#  78.68646047 10.30572115 56.90783207 37.80911658  9.03781769 24.62906183
#  29.66881367  7.91101481 13.50754581  7.55796828 20.27921173 31.97249983
#  10.82859358  0.57276745 68.52891345 17.55838029 79.5075748  55.07261682
#  82.76781477 89.02570796  0.18330733 50.37264761 96.10030782 34.47136983
#  40.18594373 53.59445224]
# [51.56389276 78.24494833 20.08871496  1.13561246  3.17210184 44.86049359
#  94.6595182  65.99074449  7.29976835 99.71491124 18.77095313 93.54295385
#  43.58759962 38.88411006 69.08966683  5.26918174 13.06255242  1.01865707
#  90.23638739 66.95498452 44.9552647   2.17373101 40.70970311  0.70605722
# ...

# %%
plt.scatter(X_data,Y_data, c='#0f0',marker='o',s=150,alpha=0.3)
plt.show()
'''
c = renk
marker = nokta şekli
s = nokta büyüklüğü
alpha = saydamlık
x data = x eksenindeki veriler
y data = y eksenindeki veriler
'''
# Out:
# '\nc = renk\nmarker = nokta şekli\ns = nokta büyüklüğü\nalpha = saydamlık\nx data = x eksenindeki veriler\ny data = y eksenindeki veriler\n'
