# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
votes=[10,2,5,6,7,8,9,10]
people=['a','b','c','d','e','f','g','h']

# %%
style.use('dark_background')

# %%
plt.pie(votes,labels=None)
plt.legend(people,loc='best')
plt.show()
